# %%
import csv
import folium
from folium import Choropleth, Circle, Marker, Icon, Map
from folium.plugins import HeatMap, MarkerCluster
import pandas as pd
import numpy as np

# %%
france_location_lat = 46.22
france_location_long = 2.21

# %%
df_Test_2 = pd.read_csv (r'1gaming_companies.csv')

map_1 = Map(location=[france_location_lat, france_location_long], zoom_start = 5)

folium.Marker([df_Test_2.iloc[19]["latitude"],df_Test_2.iloc[19]["longitude"]],
                 popup = df_Test_2.iloc[19]["name"], 
                  icon = Icon(
                    color='red',
                    opacity = 0.6,
                    prefix = "fa",
                    icon="gamepad",
                    icon_color = "black"    
                  )).add_to(map_1)

# %%
df_Test_startup3 = pd.read_csv (r'3startup_companies.csv')
np.where(df_Test_startup3["name"]=='Iminent')
# Out:
# (array([16], dtype=int64),)

# %%
np.where(df_Test_startup3["name"]=='Adknowledge')
# Out:
# (array([4], dtype=int64),)

# %%
np.where(df_Test_startup3["name"]=='Zoomorama')
# Out:
# (array([21], dtype=int64),)

# %%
np.where(df_Test_startup3["name"]=='2 Minutes')
# Out:
# (array([59], dtype=int64),)

# %%
np.where(df_Test_startup3["name"]=='Zlio')
# Out:
# (array([1], dtype=int64),)

# %%
np.where(df_Test_startup3["name"]=='blueKiwi')
# Out:
# (array([6], dtype=int64),)

# %%
df_Test_startup3 = pd.read_csv (r'3startup_companies.csv')

folium.Marker([df_Test_startup3.iloc[16]["latitude"],df_Test_startup3.iloc[16]["longitude"]],
                 popup = df_Test_startup3.iloc[16]["name"],
                  icon = Icon(
                    color='lightblue',
                    opacity = 0.6,
                    prefix = "fa",
                    icon="star",
                    icon_color = "black"
                 )).add_to(map_1)

folium.Marker([df_Test_startup3.iloc[4]["latitude"],df_Test_startup3.iloc[4]["longitude"]],
                 popup = df_Test_startup3.iloc[4]["name"],
                  icon = Icon(
                    color='lightblue',
                    opacity = 0.6,
                    prefix = "fa",
                    icon="star",
                    icon_color = "black"
                 )).add_to(map_1)

folium.Marker([df_Test_startup3.iloc[21]["latitude"],df_Test_startup3.iloc[21]["longitude"]],
                 popup = df_Test_startup3.iloc[21]["name"],
                  icon = Icon(
                    color='lightblue',
                    opacity = 0.6,
                    prefix = "fa",
                    icon="star",
                    icon_color = "black"
                 )).add_to(map_1)

folium.Marker([df_Test_startup3.iloc[59]["latitude"],df_Test_startup3.iloc[59]["longitude"]],
                 popup = df_Test_startup3.iloc[59]["name"],
                  icon = Icon(
                    color='lightblue',
                    opacity = 0.6,
                    prefix = "fa",
                    icon="star",
                    icon_color = "black"
                 )).add_to(map_1)

folium.Marker([df_Test_startup3.iloc[1]["latitude"],df_Test_startup3.iloc[1]["longitude"]],
                 popup = df_Test_startup3.iloc[1]["name"],
                  icon = Icon(
                    color='lightblue',
                    opacity = 0.6,
                    prefix = "fa",
                    icon="star",
                    icon_color = "black"
                 )).add_to(map_1)

folium.Marker([df_Test_startup3.iloc[6]["latitude"],df_Test_startup3.iloc[6]["longitude"]],
                 popup = df_Test_startup3.iloc[6]["name"],
                  icon = Icon(
                    color='lightblue',
                    opacity = 0.6,
                    prefix = "fa",
                    icon="star",
                    icon_color = "black"
                 )).add_to(map_1)

# %%
df_Test_design4 = pd.read_csv (r'2advertising_companies.csv')

folium.Marker([df_Test_design4.iloc[2]["latitude"],df_Test_design4.iloc[2]["longitude"]],
                 popup = df_Test_design3.iloc[2]["name"],
                  icon = Icon(
                    color='purple',
                    opacity = 0.6,
                    prefix = "fa",
                    icon="eye",
                    icon_color = "black"
                 )).add_to(map_1)

# %%
df_Test_kindergarden5 = pd.read_csv (r'4kindergarden.csv')

folium.Marker([df_Test_kindergarden5.iloc[5]["latitude"],df_Test_kindergarden5.iloc[5]["longitude"]],
                 popup = df_Test_kindergarden5.iloc[5]["name"],
                  icon = Icon(
                    color='beige',
                    opacity = 0.6,
                    prefix = "fa",
                    icon="child",
                    icon_color = "black"
                 )).add_to(map_1)

# %%
df_starbucks = pd.read_csv (r'5starbucks.csv')

folium.Marker([df_starbucks.iloc[7]["latitude"],df_starbucks.iloc[7]["longitude"]],
                 popup = df_starbucks.iloc[7]["name"],
                  icon = Icon(
                    color='green',
                    opacity = 0.6,
                    prefix = "fa",
                    icon="coffee",
                    icon_color = "white"
                 )).add_to(map_1)

# %%
df_vegan = pd.read_csv (r'6vegan.csv')
for i in range(0, len(df_vegan)):
    folium.Marker([df_vegan.iloc[i]["latitude"],df_vegan.iloc[i]["longitude"]],
                 popup = df_vegan.iloc[i]["name"],
                  icon = Icon(
                    color='lightgreen',
                    opacity = 0.6,
                    prefix = "fa",
                    icon="apple",
                    icon_color = "white"
                 )).add_to(map_1)

# %%
df_dog = pd.read_csv (r'7dog.csv')

folium.Marker([df_dog.iloc[2]["latitude"],df_dog.iloc[2]["longitude"]],
                 popup = df_dog.iloc[2]["name"],
                  icon = Icon(
                    color='white',
                    opacity = 0.6,
                    prefix = "fa",
                    icon="bath", #something is not working with the icon 
                    icon_color = "black"
                 )).add_to(map_1)

# %%
df_dance_club = pd.read_csv (r'9dance_club.csv')

for i in range(0, len(df_dance_club)):
    folium.Marker([df_dance_club.iloc[i]["latitude"],df_dance_club.iloc[i]["longitude"]],
                 popup = df_dance_club.iloc[i]["name"],
                  icon = Icon(
                    color='darkred',
                    opacity = 0.6,
                    prefix = "fa",
                    icon="microphone",
                    icon_color = "black"
                 )).add_to(map_1)

# %%
df_airport = pd.read_csv (r'10airport.csv')

for i in range(0, len(df_airport)):
    folium.Marker([df_airport.iloc[i]["latitude"],df_airport.iloc[i]["longitude"]],
                 popup = df_airport.iloc[i]["name"],
                  icon = Icon(
                    color='gray',
                    opacity = 0.6,
                    prefix = "fa",
                    icon="plane",
                    icon_color = "black"
                 )).add_to(map_1)
    
map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...
